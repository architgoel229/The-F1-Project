# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/combined.csv")
print(df.shape)
df.sample(10)
# Out:
# (133678, 34)
#         Unnamed: 0      Time Driver  DriverNumber  LapTime  LapNumber  Stint  \
# 47438          374  4560.237    DEV            21   97.220        8.0    1.0
# 85022         1038  4113.614    LAT             6   92.741        4.0    1.0
# 131548         286  4519.801    STR            18   91.546       27.0    2.0
# 111536         378  8629.994    STR            18   82.084       62.0    3.0
# 82265          772  7139.100    OCO            31   70.684       47.0    3.0
# 42614          127  8293.120    BOT            77   91.988       24.0    3.0
# 63873          824  6523.993    TSU            22   88.454       28.0    3.0
# 20606         1134  4214.431    PER            11   83.003        7.0    1.0
# 115285         862  9345.623    ALB            23   95.893       61.0    2.0
# 20263          778  3490.249    COL            43  128.478        1.0    1.0
#
#         PitOutTime  PitInTime  Sector1Time  ...  LapStartTime  LapStartDate  \
# 47438          NaN        NaN       36.363  ...      4463.017           NaN
# 85022          NaN        NaN       18.742  ...      4020.873           NaN
# 131548         NaN        NaN       29.112  ...      4428.255           NaN
# 111536         NaN        NaN       29.035  ...      8547.910           NaN
# 82265          NaN        NaN       17.430  ...      7068.416           NaN
# 42614          NaN        NaN       29.119  ...      8201.132           NaN
# 63873          NaN        NaN       32.725  ...      6435.539           NaN
# 20606          NaN        NaN       29.289  ...      4131.428           NaN
# 115285         NaN        NaN       28.099  ...      9249.730           NaN
# 20263          NaN        NaN          NaN  ...      3361.523           NaN
#
#         TrackStatus  Position  Deleted  DeletedReason  FastF1Generated  \
# 47438           1.0      17.0      NaN            NaN            False
# 85022           1.0      19.0      NaN            NaN            False
# 131548          1.0       5.0      NaN            NaN            False
# 111536          1.0      14.0      NaN            NaN            False
# 82265           1.0       6.0      NaN            NaN            False
# 42614           1.0       4.0      NaN            NaN            False
# 63873           1.0      15.0      NaN            NaN            False
# 20606           1.0      13.0      NaN            NaN            False
# 115285          1.0      14.0      NaN            NaN            False
# 20263         124.0      14.0      NaN            NaN            False
#
#         IsAccurate  Round  Season
# 47438         True      1    2023
# 85022         True     15    2022
# 131548        True     16    2020
# 111536        True     20    2025
# 82265         True     13    2022
# 42614         True     19    2021
# 63873         True     16    2023
# 20606         True     20    2024
# 115285        True     23    2025
# 20263        False     20    2024
#
# [10 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber',
#        'Stint', 'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time',
#        'Sector3Time', 'Sector1SessionTime', 'Sector2SessionTime',
#        'Sector3SessionTime', 'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST',
#        'IsPersonalBest', 'Compound', 'TyreLife', 'FreshTyre', 'Team',
#        'LapStartTime', 'LapStartDate', 'TrackStatus', 'Position', 'Deleted',
#        'DeletedReason', 'FastF1Generated', 'IsAccurate', 'Round', 'Season'],
#       dtype='object')

# %%
df = df[['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber',
       'Stint', 'Compound', 'TyreLife', 'Team',
       'LapStartTime', 'TrackStatus', 'Position', "Round", 'Season']].copy()

# %%
df["TrackStatus"]=df["TrackStatus"].astype(str)

# %%
df["TrackStatus"]
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 133673    1.0
# 133674    1.0
# 133675    1.0
# 133676    1.0
# 133677    1.0
# Name: TrackStatus, Length: 133678, dtype: object

# %%
df["is_clear"] = df["TrackStatus"].str.contains("1").astype(int)
df["is_yellow"] = df["TrackStatus"].str.contains("2").astype(int)
df["is_unknown"] = df["TrackStatus"].str.contains("3").astype(int)
df["is_SC"] = df["TrackStatus"].str.contains("4").astype(int)
df["is_red"] = df["TrackStatus"].str.contains("5").astype(int)
df["is_vsc"] = df["TrackStatus"].str.contains("6").astype(int)
df["is_vscEnding"] = df["TrackStatus"].str.contains("7").astype(int)

# %%
for i in df["Season"].unique(): 
    for j in df.loc[df["Season"]==i,"Round"].unique():
        minTime=df.loc[(df["Season"]==i)&(df["Round"]==j),"LapStartTime"].min()
        df.loc[(df["Season"]==i)&(df["Round"]==j),"LapStartTime"]=df.loc[(df["Season"]==i)&(df["Round"]==j),"LapStartTime"]-minTime

# %%
for i in df["Season"].unique(): 
    for j in df.loc[df["Season"]==i,"Round"].unique():
        minTime=df.loc[(df["Season"]==i)&(df["Round"]==j),"Time"].min()
        df.loc[(df["Season"]==i)&(df["Round"]==j),"Time"]=df.loc[(df["Season"]==i)&(df["Round"]==j),"Time"]-minTime

# %%
df.loc[(df["Season"]==2023)&(df["Round"]==13)].sort_values(["LapNumber"]).head(60)
# Out:
#           Time Driver  DriverNumber  LapTime  LapNumber  Stint Compound  \
# 59847    0.000    VER             1   87.912        1.0    1.0   MEDIUM
# 60961    9.516    SAR             2   97.428        1.0    1.0   MEDIUM
# 59913    1.989    NOR             4   89.901        1.0    1.0   MEDIUM
# 60177    8.110    RUS            63   96.022        1.0    1.0     HARD
# 60636   10.205    RIC             3   98.117        1.0    1.0   MEDIUM
# 60701    5.677    HUL            27   93.589        1.0    1.0   MEDIUM
# 60441    6.193    STR            18   94.105        1.0    1.0     SOFT
# 60896    7.871    MAG            20   95.783        1.0    1.0   MEDIUM
# 60309    3.872    SAI            55   91.784        1.0    1.0     SOFT
# 59979    5.156    PER            11   93.068        1.0    1.0     HARD
# 61023   19.103    OCO            31  106.965        1.0    1.0   MEDIUM
# 60243    3.416    LEC            16   91.328        1.0    1.0   MEDIUM
# 60506    8.641    ALB            23   96.553        1.0    1.0   MEDIUM
# 60111    0.772    PIA            81   88.684        1.0    1.0   MEDIUM
# 60045    2.627    HAM            44   90.539        1.0    1.0   MEDIUM
# 60831    8.821    ZHO            24   96.733        1.0    1.0   MEDIUM
# 60571    7.326    BOT            77   95.238        1.0    1.0   MEDIUM
# 60766    6.918    TSU            22   94.830        1.0    1.0     SOFT
# 60375    4.659    ALO            14   92.571        1.0    1.0   MEDIUM
# 60832   96.753    ZHO            24   87.932        2.0    1.0   MEDIUM
# 60897   95.642    MAG            20   87.771        2.0    1.0   MEDIUM
# 59980   91.926    PER            11   86.770        2.0    1.0     HARD
# 60962   97.390    SAR             2   87.874        2.0    1.0   MEDIUM
# 60507   96.171    ALB            23   87.530        2.0    1.0   MEDIUM
# 60112   86.389    PIA            81   85.617        2.0    1.0   MEDIUM
# 60310   90.102    SAI            55   86.230        2.0    1.0     SOFT
# 60637   98.103    RIC             3   87.898        2.0    1.0   MEDIUM
# 59914   87.809    NOR             4   85.820        2.0    1.0   MEDIUM
# 60178   94.882    RUS            63   86.772        2.0    1.0     HARD
# 59848   85.157    VER             1   85.157        2.0    1.0   MEDIUM
# 60442   93.195    STR            18   87.002        2.0    1.0     SOFT
# 60702   92.579    HUL            27   86.902        2.0    1.0   MEDIUM
# 60767   93.935    TSU            22   87.017        2.0    1.0     SOFT
# 60376   91.540    ALO            14   86.881        2.0    1.0   MEDIUM
# 60572   94.417    BOT            77   87.091        2.0    1.0   MEDIUM
# 60244   89.752    LEC            16   86.336        2.0    1.0   MEDIUM
# 60046   88.679    HAM            44   86.052        2.0    1.0   MEDIUM
# 59981  178.196    PER            11   86.270        3.0    1.0     HARD
# 60898  182.399    MAG            20   86.757        3.0    1.0   MEDIUM
# 60311  176.164    SAI            55   86.062        3.0    1.0     SOFT
# 60443  179.453    STR            18   86.258        3.0    1.0     SOFT
# 60179  181.719    RUS            63   86.837        3.0    1.0     HARD
# 59915  173.014    NOR             4   85.205        3.0    1.0   MEDIUM
# 60638  184.981    RIC             3   86.878        3.0    1.0   MEDIUM
# 60047  174.106    HAM            44   85.427        3.0    1.0   MEDIUM
# 60768  180.308    TSU            22   86.373        3.0    1.0     SOFT
# 60377  177.452    ALO            14   85.912        3.0    1.0   MEDIUM
# 60963  184.216    SAR             2   86.826        3.0    1.0   MEDIUM
# 60245  175.401    LEC            16   85.649        3.0    1.0   MEDIUM
# 60573  180.942    BOT            77   86.525        3.0    1.0   MEDIUM
# 60508  182.967    ALB            23   86.796        3.0    1.0   MEDIUM
# 59849  170.227    VER             1   85.070        3.0    1.0   MEDIUM
# 60703  178.888    HUL            27   86.309        3.0    1.0   MEDIUM
# 60113  171.504    PIA            81   85.115        3.0    1.0   MEDIUM
# 60833  183.527    ZHO            24   86.774        3.0    1.0   MEDIUM
# 60899  268.498    MAG            20   86.099        4.0    1.0   MEDIUM
# 59850  254.769    VER             1   84.542        4.0    1.0   MEDIUM
# 59916  257.808    NOR             4   84.794        4.0    1.0   MEDIUM
# 60114  256.389    PIA            81   84.885        4.0    1.0   MEDIUM
# 60509  269.205    ALB            23   86.238        4.0    1.0   MEDIUM
#
#        TyreLife             Team  LapStartTime  ... Position  Round  Season  \
# 59847       4.0  Red Bull Racing         0.000  ...      1.0     13    2023
# 60961       1.0         Williams         0.000  ...     17.0     13    2023
# 59913       1.0          McLaren         0.000  ...      3.0     13    2023
# 60177       1.0         Mercedes         0.000  ...     14.0     13    2023
# 60636       4.0       AlphaTauri         0.000  ...     18.0     13    2023
# 60701       4.0     Haas F1 Team         0.000  ...      9.0     13    2023
# 60441       1.0     Aston Martin         0.000  ...     10.0     13    2023
# 60896       1.0     Haas F1 Team         0.000  ...     13.0     13    2023
# 60309       1.0          Ferrari         0.000  ...      6.0     13    2023
# 59979       4.0  Red Bull Racing         0.000  ...      8.0     13    2023
# 61023       4.0           Alpine         0.000  ...     19.0     13    2023
# 60243       4.0          Ferrari         0.000  ...      5.0     13    2023
# 60506       1.0         Williams         0.000  ...     15.0     13    2023
# 60111       3.0          McLaren         0.000  ...      2.0     13    2023
# 60045       4.0         Mercedes         0.000  ...      4.0     13    2023
# 60831       4.0       Alfa Romeo         0.000  ...     16.0     13    2023
# 60571       4.0       Alfa Romeo         0.000  ...     12.0     13    2023
# 60766       1.0       AlphaTauri         0.000  ...     11.0     13    2023
# 60375       4.0     Aston Martin         0.000  ...      7.0     13    2023
# 60832       5.0       Alfa Romeo        96.979  ...     16.0     13    2023
# 60897       2.0     Haas F1 Team        96.029  ...     14.0     13    2023
# 59980       5.0  Red Bull Racing        93.314  ...      8.0     13    2023
# 60962       2.0         Williams        97.674  ...     17.0     13    2023
# 60507       2.0         Williams        96.799  ...     15.0     13    2023
# 60112       4.0          McLaren        88.930  ...      2.0     13    2023
# 60310       2.0          Ferrari        92.030  ...      6.0     13    2023
# 60637       5.0       AlphaTauri        98.363  ...     18.0     13    2023
# 59914       2.0          McLaren        90.147  ...      3.0     13    2023
# 60178       2.0         Mercedes        96.268  ...     13.0     13    2023
# 59848       5.0  Red Bull Racing        88.158  ...      1.0     13    2023
# 60442       2.0     Aston Martin        94.351  ...     10.0     13    2023
# 60702       5.0     Haas F1 Team        93.835  ...      9.0     13    2023
# 60767       2.0       AlphaTauri        95.076  ...     11.0     13    2023
# 60376       5.0     Aston Martin        92.817  ...      7.0     13    2023
# 60572       5.0       Alfa Romeo        95.484  ...     12.0     13    2023
# 60244       5.0          Ferrari        91.574  ...      5.0     13    2023
# 60046       5.0         Mercedes        90.785  ...      4.0     13    2023
# 59981       6.0  Red Bull Racing       180.084  ...      8.0     13    2023
# 60898       3.0     Haas F1 Team       183.800  ...     14.0     13    2023
# 60311       3.0          Ferrari       178.260  ...      6.0     13    2023
# 60443       3.0     Aston Martin       181.353  ...     10.0     13    2023
# 60179       3.0         Mercedes       183.040  ...     13.0     13    2023
# 59915       3.0          McLaren       175.967  ...      3.0     13    2023
# 60638       6.0       AlphaTauri       186.261  ...     18.0     13    2023
# 60047       6.0         Mercedes       176.837  ...      4.0     13    2023
# 60768       3.0       AlphaTauri       182.093  ...     11.0     13    2023
# 60377       6.0     Aston Martin       179.698  ...      7.0     13    2023
# 60963       3.0         Williams       185.548  ...     17.0     13    2023
# 60245       6.0          Ferrari       177.910  ...      5.0     13    2023
# 60573       6.0       Alfa Romeo       182.575  ...     12.0     13    2023
# 60508       3.0         Williams       184.329  ...     15.0     13    2023
# 59849       6.0  Red Bull Racing       173.315  ...      1.0     13    2023
# 60703       6.0     Haas F1 Team       180.737  ...      9.0     13    2023
# 60113       5.0          McLaren       174.547  ...      2.0     13    2023
# 60833       6.0       Alfa Romeo       184.911  ...     16.0     13    2023
# 60899       4.0     Haas F1 Team       270.557  ...     14.0     13    2023
# 59850       7.0  Red Bull Racing       258.385  ...      1.0     13    2023
# 59916       4.0          McLaren       261.172  ...      3.0     13    2023
# 60114       6.0          McLaren       259.662  ...      2.0     13    2023
# 60509       4.0         Williams       271.125  ...     15.0     13    2023
#
#        is_clear  is_yellow  is_unknown  is_SC  is_red  is_vsc  is_vscEnding
# 59847         1          1           0      0       0       0             0
# 60961         1          1           0      0       0       0             0
# 59913         1          1           0      0       0       0             0
# 60177         1          1           0      0       0       0             0
# 60636         1          1           0      0       0       0             0
# 60701         1          1           0      0       0       0             0
# 60441         1          1           0      0       0       0             0
# 60896         1          1           0      0       0       0             0
# 60309         1          1           0      0       0       0             0
# 59979         1          1           0      0       0       0             0
# 61023         1          1           0      0       0       0             0
# 60243         1          1           0      0       0       0             0
# 60506         1          1           0      0       0       0             0
# 60111         1          1           0      0       0       0             0
# 60045         1          1           0      0       0       0             0
# 60831         1          1           0      0       0       0             0
# 60571         1          1           0      0       0       0             0
# 60766         1          1           0      0       0       0             0
# 60375         1          1           0      0       0       0             0
# 60832         1          0           0      0       0       0             0
# 60897         1          0           0      0       0       0             0
# 59980         1          0           0      0       0       0             0
# 60962         1          0           0      0       0       0             0
# 60507         1          0           0      0       0       0             0
# 60112         1          0           0      0       0       0             0
# 60310         1          0           0      0       0       0             0
# 60637         1          0           0      0       0       0             0
# 59914         1          0           0      0       0       0             0
# 60178         1          0           0      0       0       0             0
# 59848         1          0           0      0       0       0             0
# 60442         1          0           0      0       0       0             0
# 60702         1          0           0      0       0       0             0
# 60767         1          0           0      0       0       0             0
# 60376         1          0           0      0       0       0             0
# 60572         1          0           0      0       0       0             0
# 60244         1          0           0      0       0       0             0
# 60046         1          0           0      0       0       0             0
# 59981         1          0           0      0       0       0             0
# 60898         1          0           0      0       0       0             0
# 60311         1          0           0      0       0       0             0
# 60443         1          0           0      0       0       0             0
# 60179         1          0           0      0       0       0             0
# 59915         1          0           0      0       0       0             0
# 60638         1          0           0      0       0       0             0
# 60047         1          0           0      0       0       0             0
# 60768         1          0           0      0       0       0             0
# 60377         1          0           0      0       0       0             0
# 60963         1          0           0      0       0       0             0
# 60245         1          0           0      0       0       0             0
# 60573         1          0           0      0       0       0             0
# 60508         1          0           0      0       0       0             0
# 59849         1          0           0      0       0       0             0
# 60703         1          0           0      0       0       0             0
# 60113         1          0           0      0       0       0             0
# 60833         1          0           0      0       0       0             0
# 60899         1          0           0      0       0       0             0
# 59850         1          0           0      0       0       0             0
# 59916         1          0           0      0       0       0             0
# 60114         1          0           0      0       0       0             0
# 60509         1          0           0      0       0       0             0
#
# [60 rows x 21 columns]

# %%
df.drop(columns=["TrackStatus"], inplace=True)

# %%
def create_data_for_round(data):
    def get_mean_lap_time(df):
        if df.empty or "LapTime" not in df.columns:
            return np.nan

        values = df["LapTime"].dropna()

        if values.empty:
            return np.nan

        return values.mean()


    def get_median_lap_time(df):
        if df.empty or "LapTime" not in df.columns:
            return np.nan

        values = df["LapTime"].dropna()

        if values.empty:
            return np.nan

        return values.median()
    
    rows=[]
    laps = data["LapNumber"].dropna().unique()

    for lap in laps:

        if lap < 5:
            continue

        if lap > data["LapNumber"].max() - 5:
            break

        for driver in data[data["LapNumber"] == lap]["Driver"].unique():


            current = data[
                (data["LapNumber"] == lap) &
                (data["Driver"] == driver)
            ]

            if current.empty:
                continue

            current = current.iloc[0]

            Driver = driver
            Position = current["Position"]
            Time = current["Time"]
            Team = current["Team"]
            Compound = current["Compound"]
            TyreLife = current["TyreLife"]
            LapTime = current["LapTime"]
            current_lap_start = current["LapStartTime"]

            if pd.isna(Position):
                continue

            Position = int(Position)


            p = data[
                (data["LapNumber"] <= lap) &
                (data["LapNumber"] > lap - 5) &
                (data["Driver"] == driver)
            ]

            if p["LapTime"].notna().sum() < 4:
                continue

            # Current driver's recent pace
            p_3 = p[p["LapNumber"] > lap - 3]

            mean_last_5 = get_mean_lap_time(p)
            median_last_5 = get_median_lap_time(p)

            mean_last_3 = get_mean_lap_time(p_3)
            median_last_3 = get_median_lap_time(p_3)


            p_minus1_driver = data[
                (data["LapNumber"] == lap) &
                (data["Position"] == Position - 1)
            ]["Driver"]

            p_minus2_driver = data[
                (data["LapNumber"] == lap) &
                (data["Position"] == Position - 2)
            ]["Driver"]

            p_minus3_driver = data[
                (data["LapNumber"] == lap) &
                (data["Position"] == Position - 3)
            ]["Driver"]

            p_plus1_driver = data[
                (data["LapNumber"] == lap) &
                (data["Position"] == Position + 1)
            ]["Driver"]

            p_plus2_driver = data[
                (data["LapNumber"] == lap) &
                (data["Position"] == Position + 2)
            ]["Driver"]

            p_plus3_driver = data[
                (data["LapNumber"] == lap) &
                (data["Position"] == Position + 3)
            ]["Driver"]

            p_minus1_driver = (
                p_minus1_driver.iloc[0]
                if not p_minus1_driver.empty
                else None
            )

            p_minus2_driver = (
                p_minus2_driver.iloc[0]
                if not p_minus2_driver.empty
                else None
            )

            p_minus3_driver = (
                p_minus3_driver.iloc[0]
                if not p_minus3_driver.empty
                else None
            )

            p_plus1_driver = (
                p_plus1_driver.iloc[0]
                if not p_plus1_driver.empty
                else None
            )

            p_plus2_driver = (
                p_plus2_driver.iloc[0]
                if not p_plus2_driver.empty
                else None
            )

            p_plus3_driver = (
                p_plus3_driver.iloc[0]
                if not p_plus3_driver.empty
                else None
            )


            p_minus1 = data[
                (data["Driver"] == p_minus1_driver) &
                (data["LapNumber"] <= lap) &
                (data["LapNumber"] > lap - 5)
            ].copy() if p_minus1_driver is not None else data.iloc[0:0].copy()

            p_minus2 = data[
                (data["Driver"] == p_minus2_driver) &
                (data["LapNumber"] <= lap) &
                (data["LapNumber"] > lap - 5)
            ].copy() if p_minus2_driver is not None else data.iloc[0:0].copy()

            p_minus3 = data[
                (data["Driver"] == p_minus3_driver) &
                (data["LapNumber"] <= lap) &
                (data["LapNumber"] > lap - 5)
            ].copy() if p_minus3_driver is not None else data.iloc[0:0].copy()

            p_plus1 = data[
                (data["Driver"] == p_plus1_driver) &
                (data["LapNumber"] <= lap) &
                (data["LapNumber"] > lap - 5)
            ].copy() if p_plus1_driver is not None else data.iloc[0:0].copy()

            p_plus2 = data[
                (data["Driver"] == p_plus2_driver) &
                (data["LapNumber"] <= lap) &
                (data["LapNumber"] > lap - 5)
            ].copy() if p_plus2_driver is not None else data.iloc[0:0].copy()

            p_plus3 = data[
                (data["Driver"] == p_plus3_driver) &
                (data["LapNumber"] <= lap) &
                (data["LapNumber"] > lap - 5)
            ].copy() if p_plus3_driver is not None else data.iloc[0:0].copy()


            p_minus1_mean_LapTime = get_mean_lap_time(p_minus1)
            p_minus2_mean_LapTime = get_mean_lap_time(p_minus2)
            p_minus3_mean_LapTime = get_mean_lap_time(p_minus3)

            p_plus1_mean_LapTime = get_mean_lap_time(p_plus1)
            p_plus2_mean_LapTime = get_mean_lap_time(p_plus2)
            p_plus3_mean_LapTime = get_mean_lap_time(p_plus3)


            p_minus1_median_LapTime = get_median_lap_time(p_minus1)
            p_minus2_median_LapTime = get_median_lap_time(p_minus2)
            p_minus3_median_LapTime = get_median_lap_time(p_minus3)

            p_plus1_median_LapTime = get_median_lap_time(p_plus1)
            p_plus2_median_LapTime = get_median_lap_time(p_plus2)
            p_plus3_median_LapTime = get_median_lap_time(p_plus3)


            p_3_minus1 = p_minus1[
                p_minus1["LapNumber"] > lap - 3
            ]

            p_3_minus2 = p_minus2[
                p_minus2["LapNumber"] > lap - 3
            ]

            p_3_minus3 = p_minus3[
                p_minus3["LapNumber"] > lap - 3
            ]

            p_3_plus1 = p_plus1[
                p_plus1["LapNumber"] > lap - 3
            ]

            p_3_plus2 = p_plus2[
                p_plus2["LapNumber"] > lap - 3
            ]

            p_3_plus3 = p_plus3[
                p_plus3["LapNumber"] > lap - 3
            ]
            p_3_minus1_mean_LapTime = get_mean_lap_time(p_3_minus1)
            p_3_minus2_mean_LapTime = get_mean_lap_time(p_3_minus2)
            p_3_minus3_mean_LapTime = get_mean_lap_time(p_3_minus3)

            p_3_plus1_mean_LapTime = get_mean_lap_time(p_3_plus1)
            p_3_plus2_mean_LapTime = get_mean_lap_time(p_3_plus2)
            p_3_plus3_mean_LapTime = get_mean_lap_time(p_3_plus3)


            p_3_minus1_median_LapTime = get_median_lap_time(p_3_minus1)
            p_3_minus2_median_LapTime = get_median_lap_time(p_3_minus2)
            p_3_minus3_median_LapTime = get_median_lap_time(p_3_minus3)

            p_3_plus1_median_LapTime = get_median_lap_time(p_3_plus1)
            p_3_plus2_median_LapTime = get_median_lap_time(p_3_plus2)
            p_3_plus3_median_LapTime = get_median_lap_time(p_3_plus3)
            def get_last_lap_time(df):

                if df.empty:
                    return np.nan

                df = df.dropna(subset=["LapTime"])

                if df.empty:
                    return np.nan

                return df.sort_values("LapNumber")["LapTime"].iloc[-1]

            p_minus1_LapTime = get_last_lap_time(p_minus1)
            p_minus2_LapTime = get_last_lap_time(p_minus2)
            p_minus3_LapTime = get_last_lap_time(p_minus3)

            p_plus1_LapTime = get_last_lap_time(p_plus1)
            p_plus2_LapTime = get_last_lap_time(p_plus2)
            p_plus3_LapTime = get_last_lap_time(p_plus3)

            def get_lap_start_time(driver_name):

                if driver_name is None:
                    return pd.NaT

                driver_lap = data[
                    (data["Driver"] == driver_name) &
                    (data["LapNumber"] == lap)
                ]

                if driver_lap.empty:
                    return pd.NaT

                return driver_lap["LapStartTime"].iloc[0]


            p_minus1_lap_start = get_lap_start_time(p_minus1_driver)
            p_minus2_lap_start = get_lap_start_time(p_minus2_driver)
            p_minus3_lap_start = get_lap_start_time(p_minus3_driver)

            p_plus1_lap_start = get_lap_start_time(p_plus1_driver)
            p_plus2_lap_start = get_lap_start_time(p_plus2_driver)
            p_plus3_lap_start = get_lap_start_time(p_plus3_driver)


            # Time separation from current driver
            p_minus1_time_delta = (
                current_lap_start - p_minus1_lap_start
                if pd.notna(p_minus1_lap_start) and pd.notna(current_lap_start)
                else np.nan
            )

            p_minus2_time_delta = (
                current_lap_start - p_minus2_lap_start
                if pd.notna(p_minus2_lap_start) and pd.notna(current_lap_start)
                else np.nan
            )

            p_minus3_time_delta = (
                current_lap_start - p_minus3_lap_start
                if pd.notna(p_minus3_lap_start) and pd.notna(current_lap_start)
                else np.nan
            )

            p_plus1_time_delta = (
                p_plus1_lap_start - current_lap_start
                if pd.notna(p_plus1_lap_start) and pd.notna(current_lap_start)
                else np.nan
            )

            p_plus2_time_delta = (
                p_plus2_lap_start - current_lap_start
                if pd.notna(p_plus2_lap_start) and pd.notna(current_lap_start)
                else np.nan
            )

            p_plus3_time_delta = (
                p_plus3_lap_start - current_lap_start
                if pd.notna(p_plus3_lap_start) and pd.notna(current_lap_start)
                else np.nan
            )

            future = data[
                (data["LapNumber"] == lap + 5) &
                (data["Driver"] == driver)
            ]

            if future.empty:
                continue

            future_position = future["Position"].iloc[0]

            if pd.isna(future_position):
                continue

            target = Position - int(future_position)


            row = {
                "Driver": Driver,
                "Position": Position,
                "Time": Time,
                "Team": Team,
                "Compound": Compound,
                "TyreLife": TyreLife,
                "LapTime": LapTime,

                "mean_last_5": mean_last_5,
                "median_last_5": median_last_5,
                "mean_last_3": mean_last_3,
                "median_last_3": median_last_3,

                "p_minus1_time_delta": p_minus1_time_delta,
                "p_minus2_time_delta": p_minus2_time_delta,
                "p_minus3_time_delta": p_minus3_time_delta,

                "p_plus1_time_delta": p_plus1_time_delta,
                "p_plus2_time_delta": p_plus2_time_delta,
                "p_plus3_time_delta": p_plus3_time_delta,

                "p_minus1_mean_LapTime": p_minus1_mean_LapTime,
                "p_minus2_mean_LapTime": p_minus2_mean_LapTime,
                "p_minus3_mean_LapTime": p_minus3_mean_LapTime,

                "p_minus1_median_LapTime": p_minus1_median_LapTime,
                "p_minus2_median_LapTime": p_minus2_median_LapTime,
                "p_minus3_median_LapTime": p_minus3_median_LapTime,

                "p_plus1_mean_LapTime": p_plus1_mean_LapTime,
                "p_plus2_mean_LapTime": p_plus2_mean_LapTime,
                "p_plus3_mean_LapTime": p_plus3_mean_LapTime,

                "p_plus1_median_LapTime": p_plus1_median_LapTime,
                "p_plus2_median_LapTime": p_plus2_median_LapTime,
                "p_plus3_median_LapTime": p_plus3_median_LapTime,

                "p_3_minus1_mean_LapTime": p_3_minus1_mean_LapTime,
                "p_3_minus2_mean_LapTime": p_3_minus2_mean_LapTime,
                "p_3_minus3_mean_LapTime": p_3_minus3_mean_LapTime,

                "p_3_minus1_median_LapTime": p_3_minus1_median_LapTime,
                "p_3_minus2_median_LapTime": p_3_minus2_median_LapTime,
                "p_3_minus3_median_LapTime": p_3_minus3_median_LapTime,

                "p_3_plus1_mean_LapTime": p_3_plus1_mean_LapTime,
                "p_3_plus2_mean_LapTime": p_3_plus2_mean_LapTime,
                "p_3_plus3_mean_LapTime": p_3_plus3_mean_LapTime,

                "p_3_plus1_median_LapTime": p_3_plus1_median_LapTime,
                "p_3_plus2_median_LapTime": p_3_plus2_median_LapTime,
                "p_3_plus3_median_LapTime": p_3_plus3_median_LapTime,

                "p_minus1_LapTime": p_minus1_LapTime,
                "p_minus2_LapTime": p_minus2_LapTime,
                "p_minus3_LapTime": p_minus3_LapTime,

                "p_plus1_LapTime": p_plus1_LapTime,
                "p_plus2_LapTime": p_plus2_LapTime,
                "p_plus3_LapTime": p_plus3_LapTime,

                "target": target
            }

            rows.append(row)

    return pd.DataFrame(rows)

# %%
datasets = []

for i in df["Season"].unique():
    for j in df.loc[df["Season"] == i, "Round"].unique():

        sdf = df[
            (df["Season"] == i) &
            (df["Round"] == j)
        ].copy()

        datasets.append(create_data_for_round(sdf))

dataset = pd.concat(datasets, ignore_index=True)

# %%
sdf = df[
    (df["Season"] == 2025) &
    (df["Round"] == 1)
].copy()

test = create_data_for_round(sdf)

# %%
test.isna().sum()
# Out:
# Driver                         0
# Position                       0
# Time                           0
# Team                           0
# Compound                       0
# TyreLife                       0
# LapTime                        0
# mean_last_5                    0
# median_last_5                  0
# mean_last_3                    0
# median_last_3                  0
# p_minus1_time_delta           68
# p_minus2_time_delta          101
# p_minus3_time_delta          139
# p_plus1_time_delta            58
# p_plus2_time_delta            96
# p_plus3_time_delta           125
# p_minus1_mean_LapTime         68
# p_minus2_mean_LapTime        101
# p_minus3_mean_LapTime        139
# p_minus1_median_LapTime       68
# p_minus2_median_LapTime      101
# p_minus3_median_LapTime      139
# p_plus1_mean_LapTime          58
# p_plus2_mean_LapTime          96
# p_plus3_mean_LapTime         125
# p_plus1_median_LapTime        58
# p_plus2_median_LapTime        96
# p_plus3_median_LapTime       125
# p_3_minus1_mean_LapTime       68
# p_3_minus2_mean_LapTime      101
# p_3_minus3_mean_LapTime      139
# p_3_minus1_median_LapTime     68
# p_3_minus2_median_LapTime    101
# p_3_minus3_median_LapTime    139
# p_3_plus1_mean_LapTime        58
# p_3_plus2_mean_LapTime        96
# p_3_plus3_mean_LapTime       125
# p_3_plus1_median_LapTime      58
# p_3_plus2_median_LapTime      96
# p_3_plus3_median_LapTime     125
# p_minus1_LapTime              68
# p_minus2_LapTime             101
# p_minus3_LapTime             139
# p_plus1_LapTime               58
# p_plus2_LapTime               96
# p_plus3_LapTime              125
# target                         0
# dtype: int64

# %%
test.sample(20)
# Out:
#     Driver  Position      Time             Team Compound  TyreLife  LapTime  \
# 283    PIA         1  2562.793          McLaren     HARD      13.0   97.112
# 163    ALB         3  1788.203         Williams   MEDIUM      19.0   98.977
# 189    NOR         2  1983.685          McLaren     HARD       6.0   97.979
# 26     HAD         9   500.618     Racing Bulls   MEDIUM       6.0   98.814
# 515    ALB         9  3964.470         Williams     HARD      21.0   97.260
# 254    ANT        11  2398.525         Mercedes     HARD      13.0   98.163
# 125    BEA         9  1500.172     Haas F1 Team     HARD      16.0   99.595
# 563    PIA         1  4203.857          McLaren     HARD      30.0   96.533
# 335    VER         6  2868.882  Red Bull Racing     HARD      17.0   97.350
# 192    OCO        10  2003.989     Haas F1 Team     HARD      10.0   97.918
# 546    RUS         3  4116.861         Mercedes     HARD      29.0   96.459
# 263    TSU         9  2393.882     Racing Bulls     HARD      14.0   98.042
# 594    DOO        15  4367.899           Alpine     HARD      34.0   98.345
# 359    HUL        17  3018.887      Kick Sauber     HARD      11.0   97.821
# 232    PIA         1  2271.310          McLaren     HARD      10.0   96.970
# 70     DOO        16   805.605           Alpine   MEDIUM       9.0   99.531
# 16     HAM         4   394.362          Ferrari   MEDIUM       5.0   97.802
# 243    DOO        16  2308.264           Alpine     HARD      13.0   99.423
# 640    VER         5  4606.228  Red Bull Racing     HARD      35.0   96.023
# 645    STR        12  4651.290     Aston Martin   MEDIUM      12.0   96.645
#
#      mean_last_5  median_last_5  mean_last_3  ...  p_3_plus1_median_LapTime  \
# 283      97.1370         97.185    97.161000  ...                    97.132
# 163      98.8620         98.941    99.039000  ...                    97.929
# 189      97.7378         97.679    97.926667  ...                    97.964
# 26       98.9532         98.895    98.818333  ...                    98.921
# 515      97.2916         97.249    97.223333  ...                    96.691
# 254      97.9222         97.875    98.026333  ...                    98.056
# 125      99.3890         99.239    99.516000  ...                    99.705
# 563      96.2510         96.319    96.406000  ...                    96.868
# 335      97.4722         97.350    97.250667  ...                    98.178
# 192      98.3928         98.086    98.015000  ...                    98.032
# 546      96.4606         96.471    96.422333  ...                    96.501
# 263      97.8512         97.903    97.879000  ...                    97.865
# 594      97.8032         97.855    98.162667  ...                    97.282
# 359      97.8632         97.797    97.935333  ...                       NaN
# 232      97.4666         97.408    97.313333  ...                    97.321
# 70       99.3922         99.396    99.416333  ...                    99.525
# 16       98.5412         98.087    97.914000  ...                    98.087
# 243      98.6594         98.525    98.768000  ...                    97.882
# 640      96.1498         96.182    96.115333  ...                    95.533
# 645      96.7714         96.645    96.734000  ...                    97.349
#
#      p_3_plus2_median_LapTime  p_3_plus3_median_LapTime  p_minus1_LapTime  \
# 283                    97.284                    97.087               NaN
# 163                    97.531                    97.426            97.679
# 189                    97.160                    97.469            97.985
# 26                     99.046                    98.701            99.055
# 515                    98.248                    97.462            97.218
# 254                    97.772                    98.561            98.099
# 125                    97.173                   100.523               NaN
# 563                    96.459                    96.496               NaN
# 335                    97.905                    97.916            97.447
# 192                    97.952                    98.619            97.716
# 546                    96.216                    95.526            96.971
# 263                    98.134                    98.056            98.933
# 594                    96.655                    97.580            96.783
# 359                    97.206                       NaN            97.426
# 232                    97.334                    97.212               NaN
# 70                    100.042                    99.052            99.354
# 16                     98.614                    98.797            97.821
# 243                    99.788                    98.192            98.047
# 640                    96.841                    96.725            96.541
# 645                    97.288                    97.096            96.551
#
#      p_minus2_LapTime  p_minus3_LapTime  p_plus1_LapTime  p_plus2_LapTime  \
# 283               NaN               NaN           96.754           97.057
# 163            97.211               NaN           97.929           97.075
# 189               NaN               NaN           97.964           97.160
# 26             98.911            98.779           98.964           99.123
# 515            97.141            95.069           96.582           97.241
# 254            98.042            98.933           98.263           97.774
# 125            97.942            99.094          100.219           97.024
# 563               NaN               NaN           96.743           96.576
# 335            97.474            97.190           98.178           97.995
# 192            98.787            99.383           97.657           97.875
# 546            96.366               NaN           96.496           96.242
# 263            98.884            97.722           98.099           98.163
# 594            97.193            97.086           98.600           96.932
# 359            98.422            98.252              NaN           97.206
# 232               NaN               NaN           96.952           97.334
# 70             99.237            99.172           99.743          100.042
# 16             97.917            98.082           98.253           98.895
# 243            98.561            97.772           98.033           99.890
# 640            96.192            95.708           95.260           96.432
# 645            96.836            96.373           97.349           97.317
#
#      p_plus3_LapTime  target
# 283           97.087       0
# 163           96.907     -10
# 189           99.319       0
# 26            99.162       1
# 515           97.462       0
# 254           98.373       1
# 125          100.523       1
# 563           96.462       0
# 335           98.017       0
# 192           98.898       0
# 546           95.526       0
# 263           98.263       1
# 594           97.580       1
# 359              NaN      -1
# 232           97.360       0
# 70            98.897      -2
# 16            98.797       0
# 243           98.457       1
# 640           96.431       1
# 645           97.194       0
#
# [20 rows x 48 columns]

# %%
test.shape
# Out:
# (707, 44)

# %%
dataset.shape
# Out:
# (87908, 44)

# %%
dataset.isnull().sum()
# Out:
# Driver                           0
# Position                         0
# Time                             0
# Team                             0
# Compound                         0
# TyreLife                       631
# LapTime                        116
# p_minus1_time_delta           7816
# p_minus2_time_delta          12571
# p_minus3_time_delta          17308
# p_plus1_time_delta            7151
# p_plus2_time_delta           11302
# p_plus3_time_delta           15727
# p_minus1_mean_LapTime         7816
# p_minus2_mean_LapTime        12571
# p_minus3_mean_LapTime        17308
# p_minus1_median_LapTime       7816
# p_minus2_median_LapTime      12571
# p_minus3_median_LapTime      17308
# p_plus1_mean_LapTime          7151
# p_plus2_mean_LapTime         11302
# p_plus3_mean_LapTime         15727
# p_plus1_median_LapTime        7151
# p_plus2_median_LapTime       11302
# p_plus3_median_LapTime       15727
# p_3_minus1_mean_LapTime       7827
# p_3_minus2_mean_LapTime      12590
# p_3_minus3_mean_LapTime      17323
# p_3_minus1_median_LapTime     7827
# p_3_minus2_median_LapTime    12590
# p_3_minus3_median_LapTime    17323
# p_3_plus1_mean_LapTime        7161
# p_3_plus2_mean_LapTime       11309
# p_3_plus3_mean_LapTime       15734
# p_3_plus1_median_LapTime      7161
# p_3_plus2_median_LapTime     11309
# p_3_plus3_median_LapTime     15734
# p_minus1_LapTime              7816
# p_minus2_LapTime             12571
# p_minus3_LapTime             17308
# p_plus1_LapTime               7151
# p_plus2_LapTime              11302
# p_plus3_LapTime              15727
# target                           0
# dtype: int64

# %%
dataset.dropna().shape
# Out:
# (49653, 44)

# %%
dataset
# Out:
#       Driver  Position      Time               Team Compound  TyreLife  \
# 0        VER         1   375.957    Red Bull Racing   MEDIUM       5.0
# 1        PER         2   378.418    Red Bull Racing   MEDIUM       5.0
# 2        ALO         5   382.423       Aston Martin   MEDIUM       6.0
# 3        LEC         3   379.499            Ferrari   MEDIUM       5.0
# 4        SAR        18   397.992           Williams   MEDIUM       5.0
# ...      ...       ...       ...                ...      ...       ...
# 87903    SAI         4  5131.386            McLaren   MEDIUM      27.0
# 87904    RAI        14  5142.633  Alfa Romeo Racing     SOFT      20.0
# 87905    BOT         8  5134.645           Mercedes     HARD      33.0
# 87906    AIT        16  5150.205           Williams     SOFT      23.0
# 87907    GIO        12  5140.825  Alfa Romeo Racing   MEDIUM      28.0
#
#        LapTime  p_minus1_time_delta  p_minus2_time_delta  p_minus3_time_delta  \
# 0       93.955                  NaN                  NaN                  NaN
# 1       94.085                2.331                  NaN                  NaN
# 2       94.512                0.661                2.794                3.578
# 3       94.382                0.784                3.115                  NaN
# 4       96.204                0.579                1.242                1.892
# ...        ...                  ...                  ...                  ...
# 87903   57.648                0.966                2.170               11.235
# 87904   57.870                0.354                1.688                3.048
# 87905   57.198                1.419                2.016                2.749
# 87906   58.012                2.975                7.430                7.784
# 87907   57.750                1.360                2.952                4.015
#
#        ...  p_3_plus1_median_LapTime  p_3_plus2_median_LapTime  \
# 0      ...                    94.055                    94.549
# 1      ...                    94.549                    94.557
# 2      ...                    94.902                    95.150
# 3      ...                    94.557                    94.512
# 4      ...                    96.526                       NaN
# ...    ...                       ...                       ...
# 87903  ...                    57.262                    57.278
# 87904  ...                    58.202                    58.018
# 87905  ...                    57.362                    57.356
# 87906  ...                    58.690                       NaN
# 87907  ...                    56.542                    57.870
#
#        p_3_plus3_median_LapTime  p_minus1_LapTime  p_minus2_LapTime  \
# 0                        94.557               NaN               NaN
# 1                        94.512            93.955               NaN
# 2                        95.184            94.557            94.382
# 3                        94.902            94.085            93.955
# 4                           NaN            96.244            96.003
# ...                         ...               ...               ...
# 87903                    57.105            57.554            57.557
# 87904                    58.690            56.777            57.750
# 87905                    57.670            57.448            57.339
# 87906                       NaN            58.202            57.870
# 87907                    58.202            57.670            57.356
#
#        p_minus3_LapTime  p_plus1_LapTime  p_plus2_LapTime  p_plus3_LapTime  \
# 0                   NaN           94.085           94.382           94.557
# 1                   NaN           94.382           94.557           94.512
# 2                94.085           94.902           95.150           95.107
# 3                   NaN           94.557           94.512           94.902
# 4                95.699           96.238              NaN              NaN
# ...                 ...              ...              ...              ...
# 87903            57.394           57.492           57.339           57.448
# 87904            57.670           58.202           58.012           59.696
# 87905            57.492           57.590           57.356           57.670
# 87906            56.777           59.696              NaN              NaN
# 87907            57.590           56.777           57.870           58.202
#
#        target
# 0          -1
# 1          -2
# 2          -2
# 3          -2
# 4           1
# ...       ...
# 87903       0
# 87904       0
# 87905       0
# 87906       0
# 87907      -1
#
# [87908 rows x 44 columns]

# %%
dataset.to_csv("../data/model1_dataset.csv")
